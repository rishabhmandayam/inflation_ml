# %%
import numpy as np
import polars as pl

# %%
df = pl.read_csv("../data/current.csv", infer_schema_length=10000, dtypes={"ANDENOx": pl.Float64})

display(df.head())

print("\nDataframe info:")
print(f"Shape: {df.shape}")
print(f"Column names: {df.columns}")
print(f"Data types:\n{df.dtypes}")
# Out:
# /var/folders/jb/ckb_b9f94m5dvhsy6d9bwn800000gn/T/ipykernel_97340/390444862.py:1: DeprecationWarning: The argument `dtypes` for `read_csv` is deprecated. It has been renamed to `schema_overrides`.
#   df = pl.read_csv("../data/current.csv", infer_schema_length=10000, dtypes={"ANDENOx": pl.Float64})
# shape: (5, 127)
# ┌────────────┬──────────┬─────────┬───────────────┬───┬─────────────┬──────────┬─────────┬─────────┐
# │ sasdate    ┆ RPI      ┆ W875RX1 ┆ DPCERA3M086SB ┆ … ┆ DTCOLNVHFNM ┆ DTCTHFNM ┆ INVEST  ┆ VIXCLSx │
# │ ---        ┆ ---      ┆ ---     ┆ EA            ┆   ┆ ---         ┆ ---      ┆ ---     ┆ ---     │
# │ str        ┆ f64      ┆ f64     ┆ ---           ┆   ┆ f64         ┆ f64      ┆ f64     ┆ f64     │
# │            ┆          ┆         ┆ f64           ┆   ┆             ┆          ┆         ┆         │
# ╞════════════╪══════════╪═════════╪═══════════════╪═══╪═════════════╪══════════╪═════════╪═════════╡
# │ Transform: ┆ 5.0      ┆ 5.0     ┆ 5.0           ┆ … ┆ 6.0         ┆ 6.0      ┆ 6.0     ┆ 1.0     │
# │ 1/1/1959   ┆ 2583.56  ┆ 2426.0  ┆ 15.188        ┆ … ┆ 6476.0      ┆ 12298.0  ┆ 84.2043 ┆ null    │
# │ 2/1/1959   ┆ 2593.596 ┆ 2434.8  ┆ 15.346        ┆ … ┆ 6476.0      ┆ 12298.0  ┆ 83.528  ┆ null    │
# │ 3/1/1959   ┆ 2610.396 ┆ 2452.7  ┆ 15.491        ┆ … ┆ 6508.0      ┆ 12349.0  ┆ 81.6405 ┆ null    │
# │ 4/1/1959   ┆ 2627.446 ┆ 2470.0  ┆ 15.435        ┆ … ┆ 6620.0      ┆ 12484.0  ┆ 81.8099 ┆ null    │
# └────────────┴──────────┴─────────┴───────────────┴───┴─────────────┴──────────┴─────────┴─────────┘
# Dataframe info:
# Shape: (794, 127)
# Column names: ['sasdate', 'RPI', 'W875RX1', 'DPCERA3M086SBEA', 'CMRMTSPLx', 'RETAILx', 'INDPRO', 'IPFPNSS', 'IPFINAL', 'IPCONGD', 'IPDCONGD', 'IPNCONGD', 'IPBUSEQ', 'IPMAT', 'IPDMAT', 'IPNMAT', 'IPMANSICS', 'IPB51222S', 'IPFUELS', 'CUMFNS', 'HWI', 'HWIURATIO', 'CLF16OV', 'CE16OV', 'UNRATE', 'UEMPMEAN', 'UEMPLT5', 'UEMP5TO14', 'UEMP15OV', 'UEMP15T26', 'UEMP27OV', 'CLAIMSx', 'PAYEMS', 'USGOOD', 'CES1021000001', 'USCONS', 'MANEMP', 'DMANEMP', 'NDMANEMP', 'SRVPRD', 'USTPU', 'USWTRADE', 'USTRADE', 'USFIRE', 'USGOVT', 'CES0600000007', 'AWOTMAN', 'AWHMAN', 'HOUST', 'HOUSTNE', 'HOUSTMW', 'HOUSTS', 'HOUSTW', 'PERMIT', 'PERMITNE', 'PERMITMW', 'PERMITS', 'PERMITW', 'ACOGNO', 'AMDMNOx', 'ANDENOx', 'AMDMUOx', 'BUSINVx', 'ISRATIOx', 'M1SL', 'M2SL', 'M2REAL', 'BOGMBASE', 'TOTRESNS', 'NONBORRES', 'BUSLOANS', 'REALLN', 'NONREVSL', 'CONSPI', 'S&P 500', 'S&P div yield', 'S&P PE ratio', 'FEDFUNDS', 'CP3Mx', 'TB3MS', 'TB6MS', 'GS1', 'GS5', 'GS10', 'AAA', 'BAA', 'COMPAPFFx', 'TB3SMFFM', 'TB6SMFFM', 'T1YFFM', 'T5YFFM', 'T10YFFM', 'AAAFFM', 'BAAFFM', 'TWEXAFEGSMTHx', 'EXSZUSx', 'EXJPUSx', 'EXUSUKx', 'EXCAUSx', 'WPSFD49207', 'WPSFD49502', 'WPSID61', 'WPSID62', 'OILPRICEx', 'PPICMM', 'CPIAUCSL', 'CPIAPPSL', 'CPITRNSL', 'CPIMEDSL', 'CUSR0000SAC', 'CUSR0000SAD', 'CUSR0000SAS', 'CPIULFSL', 'CUSR0000SA0L2', 'CUSR0000SA0L5', 'PCEPI', 'DDURRG3M086SBEA', 'DNDGRG3M086SBEA', 'DSERRG3M086SBEA', 'CES0600000008', 'CES2000000008', 'CES3000000008', 'UMCSENTx', 'DTCOLNVHFNM', 'DTCTHFNM', 'INVEST', 'VIXCLSx']
# Data types:
# [String, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Int64, Float64, Int64, Int64, Float64, Float64, Int64, Int64, Int64, Int64, Int64, Int64, Int64, Int64, Float64, Int64, Int64, Int64, Int64, Int64, Int64, Float64, Float64, Int64, Int64, Float64, Float64, Float64, Int64, Int64, Int64, Int64, Int64, Int64, Int64, Int64, Int64, Int64, Int64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64, Float64]

# %%
data_dictionary = pl.read_csv(
    "../data/dictionary.csv", 
    infer_schema_length=10000, 
    dtypes={"description": pl.Utf8},
    ignore_errors=True
)

display(data_dictionary.head())

print("\nDataframe info:")
print(f"Shape: {data_dictionary.shape}")
print(f"Column names: {data_dictionary.columns}")
print(f"Data types:\n{data_dictionary.dtypes}")
# Out:
# /var/folders/jb/ckb_b9f94m5dvhsy6d9bwn800000gn/T/ipykernel_97340/2145664401.py:1: DeprecationWarning: The argument `dtypes` for `read_csv` is deprecated. It has been renamed to `schema_overrides`.
#   data_dictionary = pl.read_csv(
# shape: (5, 7)
# ┌─────┬───────┬─────────────────┬────────────────────────┬─────────────┬───────────────────┬───────┐
# │ id  ┆ tcode ┆ fred            ┆ description            ┆ gsi         ┆ gsi:description   ┆ group │
# │ --- ┆ ---   ┆ ---             ┆ ---                    ┆ ---         ┆ ---               ┆ ---   │
# │ i64 ┆ i64   ┆ str             ┆ str                    ┆ str         ┆ str               ┆ i64   │
# ╞═════╪═══════╪═════════════════╪════════════════════════╪═════════════╪═══════════════════╪═══════╡
# │ 1   ┆ 5     ┆ RPI             ┆ Real Personal Income   ┆ M_14386177  ┆ PI                ┆ 1     │
# │ 2   ┆ 5     ┆ W875RX1         ┆ Real personal income   ┆ M_145256755 ┆ PI less transfers ┆ 1     │
# │     ┆       ┆                 ┆ ex transf…             ┆             ┆                   ┆       │
# │ 3   ┆ 5     ┆ DPCERA3M086SBEA ┆ Real personal          ┆ M_123008274 ┆ Real Consumption  ┆ 4     │
# │     ┆       ┆                 ┆ consumption expe…      ┆             ┆                   ┆       │
# │ 4   ┆ 5     ┆ CMRMTSPLx       ┆ Real Manu.  and Trade  ┆ M_110156998 ┆ M&T sales         ┆ 4     │
# │     ┆       ┆                 ┆ Industri…              ┆             ┆                   ┆       │
# │ 5   ┆ 5     ┆ RETAILx         ┆ Retail and Food        ┆ M_130439509 ┆ Retail sales      ┆ 4     │
# │     ┆       ┆                 ┆ Services Sales         ┆             ┆                   ┆       │
# └─────┴───────┴─────────────────┴────────────────────────┴─────────────┴───────────────────┴───────┘
# Dataframe info:
# Shape: (126, 7)
# Column names: ['id', 'tcode', 'fred', 'description', 'gsi', 'gsi:description', 'group']
# Data types:
# [Int64, Int64, String, String, String, String, Int64]

# %%
df = df.slice(1)
display(df.head())
# Out:
# shape: (5, 127)
# ┌──────────┬──────────┬─────────┬─────────────────┬───┬─────────────┬──────────┬─────────┬─────────┐
# │ sasdate  ┆ RPI      ┆ W875RX1 ┆ DPCERA3M086SBEA ┆ … ┆ DTCOLNVHFNM ┆ DTCTHFNM ┆ INVEST  ┆ VIXCLSx │
# │ ---      ┆ ---      ┆ ---     ┆ ---             ┆   ┆ ---         ┆ ---      ┆ ---     ┆ ---     │
# │ str      ┆ f64      ┆ f64     ┆ f64             ┆   ┆ f64         ┆ f64      ┆ f64     ┆ f64     │
# ╞══════════╪══════════╪═════════╪═════════════════╪═══╪═════════════╪══════════╪═════════╪═════════╡
# │ 1/1/1959 ┆ 2583.56  ┆ 2426.0  ┆ 15.188          ┆ … ┆ 6476.0      ┆ 12298.0  ┆ 84.2043 ┆ null    │
# │ 2/1/1959 ┆ 2593.596 ┆ 2434.8  ┆ 15.346          ┆ … ┆ 6476.0      ┆ 12298.0  ┆ 83.528  ┆ null    │
# │ 3/1/1959 ┆ 2610.396 ┆ 2452.7  ┆ 15.491          ┆ … ┆ 6508.0      ┆ 12349.0  ┆ 81.6405 ┆ null    │
# │ 4/1/1959 ┆ 2627.446 ┆ 2470.0  ┆ 15.435          ┆ … ┆ 6620.0      ┆ 12484.0  ┆ 81.8099 ┆ null    │
# │ 5/1/1959 ┆ 2642.72  ┆ 2486.4  ┆ 15.622          ┆ … ┆ 6753.0      ┆ 12646.0  ┆ 80.7315 ┆ null    │
# └──────────┴──────────┴─────────┴─────────────────┴───┴─────────────┴──────────┴─────────┴─────────┘

# %%
print(df.select('CPIAUCSL').describe())
# Out:
# shape: (9, 2)
# ┌────────────┬────────────┐
# │ statistic  ┆ CPIAUCSL   │
# │ ---        ┆ ---        │
# │ str        ┆ f64        │
# ╞════════════╪════════════╡
# │ count      ┆ 793.0      │
# │ null_count ┆ 0.0        │
# │ mean       ┆ 139.123421 │
# │ std        ┆ 83.861756  │
# │ min        ┆ 28.97      │
# │ 25%        ┆ 54.0       │
# │ 50%        ┆ 138.3      │
# │ 75%        ┆ 212.709    │
# │ max        ┆ 319.086    │
# └────────────┴────────────┘

# %%
tcode5_cols = data_dictionary.filter(pl.col("tcode") == 5)["fred"].to_list()
tcode6_cols = data_dictionary.filter(pl.col("tcode") == 6)["fred"].to_list()
cols_to_transform = tcode5_cols + tcode6_cols

# %%
def add_transformations(df, columns):
    # Create expressions for all transformations
    mom_exprs = []
    yoy_exprs = []
    
    for col in columns:
        if col in df.columns:
            mom_expr = (
                ((pl.col(col) - pl.col(col).shift(1)) / pl.col(col).shift(1) * 100)
                .alias(f"{col}_MOM")
            )
            mom_exprs.append(mom_expr)
            
            yoy_expr = (
                ((pl.col(col) - pl.col(col).shift(12)) / pl.col(col).shift(12) * 100)
                .alias(f"{col}_YOY")
            )
            yoy_exprs.append(yoy_expr)
    
    return df.with_columns(mom_exprs + yoy_exprs)

df = add_transformations(df, cols_to_transform)

print(f"Added {len(cols_to_transform)} MOM and {len(cols_to_transform)} YOY transformations")
# Out:
# Added 85 MOM and 85 YOY transformations

# %%
print(df.select('CPIAUCSL_YOY').describe())
# Out:
# shape: (9, 2)
# ┌────────────┬──────────────┐
# │ statistic  ┆ CPIAUCSL_YOY │
# │ ---        ┆ ---          │
# │ str        ┆ f64          │
# ╞════════════╪══════════════╡
# │ count      ┆ 781.0        │
# │ null_count ┆ 12.0         │
# │ mean       ┆ 3.758927     │
# │ std        ┆ 2.805136     │
# │ min        ┆ -1.958761    │
# │ 25%        ┆ 1.825069     │
# │ 50%        ┆ 3.01941      │
# │ 75%        ┆ 4.678363     │
# │ max        ┆ 14.592275    │
# └────────────┴──────────────┘

# %%
print(df.select('CPIAUCSL_MOM').describe())
# Out:
# shape: (9, 2)
# ┌────────────┬──────────────┐
# │ statistic  ┆ CPIAUCSL_MOM │
# │ ---        ┆ ---          │
# │ str        ┆ f64          │
# ╞════════════╪══════════════╡
# │ count      ┆ 792.0        │
# │ null_count ┆ 1.0          │
# │ mean       ┆ 0.303703     │
# │ std        ┆ 0.313489     │
# │ min        ┆ -1.770548    │
# │ 25%        ┆ 0.127389     │
# │ 50%        ┆ 0.262614     │
# │ 75%        ┆ 0.442478     │
# │ max        ┆ 1.809955     │
# └────────────┴──────────────┘

# %%
import plotly.express as px
df = df.with_columns(
    pl.col('sasdate').str.strptime(pl.Date, format="%m/%d/%Y").alias('sasdate')
)

fig = px.line(df, x='sasdate', y='CPIAUCSL', title='Consumer Price Index Over Time')
fig.show()

# %%
fig = px.line(df, x='sasdate', y='CPIAUCSL_YOY', title='CPI 12 month change')
fig.show()

# %%
fig = px.line(df, x='sasdate', y='CPIAUCSL_MOM', title='CPI month to month change')
fig.show()

# %%
numerical_cols = [col for col in df.columns if col not in ['sasdate', 'date', 'CPIAUCSL_YOY']]
correlation_results = []
for col in numerical_cols:
    if df[col].dtype not in [pl.Float64, pl.Int64]:
        continue
        
    temp_df = df.select([
        col,
        'CPIAUCSL_YOY'
    ]).with_columns([
        pl.col(col).shift(-1).alias(f"{col}_lag1")  
    ])
    
    correlation = temp_df.filter(
        pl.col(f"{col}_lag1").is_not_null() & 
        pl.col("CPIAUCSL_YOY").is_not_null()
    ).select(
        pl.corr(f"{col}_lag1", "CPIAUCSL_YOY").alias("correlation")
    )[0, 0]
    
    correlation_results.append({"feature": col, "correlation": correlation})

corr_df = pl.DataFrame(correlation_results)
corr_df = corr_df.with_columns(pl.col("correlation").abs().alias("abs_correlation"))
corr_df = corr_df.sort("abs_correlation", descending=True)

print("Top 15 features with highest correlation to next month's inflation:")
print(corr_df.head(15))
# Out:
# Top 15 features with highest correlation to next month's inflation:
# shape: (15, 3)
# ┌─────────────────────┬─────────────┬─────────────────┐
# │ feature             ┆ correlation ┆ abs_correlation │
# │ ---                 ┆ ---         ┆ ---             │
# │ str                 ┆ f64         ┆ f64             │
# ╞═════════════════════╪═════════════╪═════════════════╡
# │ CUSR0000SA0L5_YOY   ┆ 0.987645    ┆ 0.987645        │
# │ CPIULFSL_YOY        ┆ 0.977698    ┆ 0.977698        │
# │ PCEPI_YOY           ┆ 0.977024    ┆ 0.977024        │
# │ CUSR0000SA0L2_YOY   ┆ 0.960428    ┆ 0.960428        │
# │ DSERRG3M086SBEA_YOY ┆ 0.9227      ┆ 0.9227          │
# │ …                   ┆ …           ┆ …               │
# │ WPSFD49502_YOY      ┆ 0.791769    ┆ 0.791769        │
# │ CES0600000008_YOY   ┆ 0.790133    ┆ 0.790133        │
# │ CES3000000008_YOY   ┆ 0.787761    ┆ 0.787761        │
# │ DSERRG3M086SBEA_MOM ┆ 0.784826    ┆ 0.784826        │
# │ CUSR0000SAD_YOY     ┆ 0.771591    ┆ 0.771591        │
# └─────────────────────┴─────────────┴─────────────────┘

# %%
import plotly.express as px

# Get top 10 features
top10_features = corr_df.head(10)["feature"].to_list()
top10_corrs = corr_df.head(10)["correlation"].to_list()

# Create bar chart
fig = px.bar(
    x=top10_features, 
    y=top10_corrs,
    title="Top 10 Lagged Features Correlation with Next Month's Inflation",
    labels={'x': 'Feature', 'y': 'Correlation Coefficient'},
    color=top10_corrs,
    color_continuous_scale=px.colors.diverging.RdBu_r
)

fig.update_layout(xaxis_tickangle=-45)
fig.show()

# %%
for feature in top10_features[:3]:
    scatter_df = df.select([
        feature,
        'CPIAUCSL_YOY'
    ]).with_columns([
        pl.col(feature).shift(-1).alias(f"{feature}_lag1")
    ]).filter(
        pl.col(f"{feature}_lag1").is_not_null() & 
        pl.col("CPIAUCSL_YOY").is_not_null()
    )
    
    fig = px.scatter(
        scatter_df, 
        x=f"{feature}_lag1", 
        y="CPIAUCSL_YOY",
        title=f"Scatter plot of lagged {feature} vs. Inflation",
        trendline="ols"
    )
    
    fig.show()

# %%
numerical_cols = [col for col in df.columns if col not in ['sasdate', 'date', 'CPIAUCSL_YOY']]
correlation_results = []
for col in numerical_cols:
    if df[col].dtype not in [pl.Float64, pl.Int64]:
        continue
        
    # Filter for data points post 2008
    post_2008_df = df.filter(pl.col("sasdate") >= pl.date(2008, 1, 1))

    
    temp_df = post_2008_df.select([
        col,
        'CPIAUCSL_YOY'
    ]).with_columns([
        pl.col(col).shift(-1).alias(f"{col}_lag1")  
    ])
    
    correlation = temp_df.filter(
        pl.col(f"{col}_lag1").is_not_null() & 
        pl.col("CPIAUCSL_YOY").is_not_null()
    ).select(
        pl.corr(f"{col}_lag1", "CPIAUCSL_YOY").alias("correlation")
    )[0, 0]
    
    correlation_results.append({"feature": col, "correlation": correlation})

corr_df = pl.DataFrame(correlation_results)
corr_df = corr_df.with_columns(pl.col("correlation").abs().alias("abs_correlation"))
corr_df = corr_df.sort("abs_correlation", descending=True)

print("Top 15 features with highest correlation to next month's inflation (post 2008):")
print(corr_df.head(15))
# Out:
# Top 15 features with highest correlation to next month's inflation (post 2008):
# shape: (15, 3)
# ┌─────────────────────┬─────────────┬─────────────────┐
# │ feature             ┆ correlation ┆ abs_correlation │
# │ ---                 ┆ ---         ┆ ---             │
# │ str                 ┆ f64         ┆ f64             │
# ╞═════════════════════╪═════════════╪═════════════════╡
# │ CUSR0000SA0L5_YOY   ┆ 0.973066    ┆ 0.973066        │
# │ PCEPI_YOY           ┆ 0.970766    ┆ 0.970766        │
# │ CPIULFSL_YOY        ┆ 0.95357     ┆ 0.95357         │
# │ CUSR0000SA0L2_YOY   ┆ 0.918091    ┆ 0.918091        │
# │ DSERRG3M086SBEA_YOY ┆ 0.870448    ┆ 0.870448        │
# │ …                   ┆ …           ┆ …               │
# │ WPSID61             ┆ 0.768117    ┆ 0.768117        │
# │ CPITRNSL_YOY        ┆ 0.751114    ┆ 0.751114        │
# │ BUSINVx_YOY         ┆ 0.743091    ┆ 0.743091        │
# │ CUSR0000SAS_YOY     ┆ 0.739593    ┆ 0.739593        │
# │ WPSID61_YOY         ┆ 0.735838    ┆ 0.735838        │
# └─────────────────────┴─────────────┴─────────────────┘

# %%
post_2008_df.head(5)
# Out:
# shape: (5, 295)
# ┌────────────┬───────────┬─────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ sasdate    ┆ RPI       ┆ W875RX1 ┆ DPCERA3M0 ┆ … ┆ CES300000 ┆ DTCOLNVHF ┆ DTCTHFNM_ ┆ INVEST_YO │
# │ ---        ┆ ---       ┆ ---     ┆ 86SBEA    ┆   ┆ 0008_YOY  ┆ NM_YOY    ┆ YOY       ┆ Y         │
# │ date       ┆ f64       ┆ f64     ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │            ┆           ┆         ┆ f64       ┆   ┆ f64       ┆ f64       ┆ f64       ┆ f64       │
# ╞════════════╪═══════════╪═════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 2008-01-01 ┆ 13862.766 ┆ 11830.2 ┆ 85.272    ┆ … ┆ 2.880658  ┆ 1.547442  ┆ 7.915992  ┆ 3.363856  │
# │ 2008-02-01 ┆ 13877.177 ┆ 11841.2 ┆ 84.977    ┆ … ┆ 3.049853  ┆ 1.125644  ┆ 7.858323  ┆ 3.503742  │
# │ 2008-03-01 ┆ 13893.695 ┆ 11844.7 ┆ 85.189    ┆ … ┆ 3.040936  ┆ 0.142674  ┆ 7.280178  ┆ 3.004629  │
# │ 2008-04-01 ┆ 13854.44  ┆ 11775.0 ┆ 85.327    ┆ … ┆ 2.5       ┆ -0.223612 ┆ 6.293236  ┆ 1.993345  │
# │ 2008-05-01 ┆ 14441.892 ┆ 11728.6 ┆ 85.486    ┆ … ┆ 2.552204  ┆ -0.905268 ┆ 5.672997  ┆ 2.663956  │
# └────────────┴───────────┴─────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %% [markdown]
# ## Feature Selection using Lasso

# %%
from sklearn.linear_model import LassoCV
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import TimeSeriesSplit
import matplotlib.pyplot as plt

# %%
def prepare_lagged_features(input_df, target_col='CPIAUCSL_YOY', lag=1):    
    available_cols = [col for col in numerical_cols if col in input_df.columns]
    print(available_cols)
    
    lagged_cols = [pl.col(col).shift(lag).alias(f"{col}_lag{lag}") for col in available_cols]
    
    # Apply lagged columns to the full DataFrame
    model_df = input_df.with_columns(lagged_cols)
    # Then select only the target and the new lagged columns
    model_df = model_df.select([pl.col(target_col)] + [pl.col(f"{col}_lag{lag}") for col in available_cols])
    model_df = model_df.drop_nulls()
    
    return model_df

# %%
model_df = prepare_lagged_features(df)
y = model_df['CPIAUCSL_YOY'].to_numpy()
feature_names = [col for col in model_df.columns if col != 'CPIAUCSL_YOY']
X = model_df.select(feature_names).to_numpy()
# Out:
# ['RPI', 'W875RX1', 'DPCERA3M086SBEA', 'CMRMTSPLx', 'RETAILx', 'INDPRO', 'IPFPNSS', 'IPFINAL', 'IPCONGD', 'IPDCONGD', 'IPNCONGD', 'IPBUSEQ', 'IPMAT', 'IPDMAT', 'IPNMAT', 'IPMANSICS', 'IPB51222S', 'IPFUELS', 'CUMFNS', 'HWI', 'HWIURATIO', 'CLF16OV', 'CE16OV', 'UNRATE', 'UEMPMEAN', 'UEMPLT5', 'UEMP5TO14', 'UEMP15OV', 'UEMP15T26', 'UEMP27OV', 'CLAIMSx', 'PAYEMS', 'USGOOD', 'CES1021000001', 'USCONS', 'MANEMP', 'DMANEMP', 'NDMANEMP', 'SRVPRD', 'USTPU', 'USWTRADE', 'USTRADE', 'USFIRE', 'USGOVT', 'CES0600000007', 'AWOTMAN', 'AWHMAN', 'HOUST', 'HOUSTNE', 'HOUSTMW', 'HOUSTS', 'HOUSTW', 'PERMIT', 'PERMITNE', 'PERMITMW', 'PERMITS', 'PERMITW', 'ACOGNO', 'AMDMNOx', 'ANDENOx', 'AMDMUOx', 'BUSINVx', 'ISRATIOx', 'M1SL', 'M2SL', 'M2REAL', 'BOGMBASE', 'TOTRESNS', 'NONBORRES', 'BUSLOANS', 'REALLN', 'NONREVSL', 'CONSPI', 'S&P 500', 'S&P div yield', 'S&P PE ratio', 'FEDFUNDS', 'CP3Mx', 'TB3MS', 'TB6MS', 'GS1', 'GS5', 'GS10', 'AAA', 'BAA', 'COMPAPFFx', 'TB3SMFFM', 'TB6SMFFM', 'T1YFFM', 'T5YFFM', 'T10YFFM', 'AAAFFM', 'BAAFFM', 'TWEXAFEGSMTHx', 'EXSZUSx', 'EXJPUSx', 'EXUSUKx', 'EXCAUSx', 'WPSFD49207', 'WPSFD49502', 'WPSID61', 'WPSID62', 'OILPRICEx', 'PPICMM', 'CPIAUCSL', 'CPIAPPSL', 'CPITRNSL', 'CPIMEDSL', 'CUSR0000SAC', 'CUSR0000SAD', 'CUSR0000SAS', 'CPIULFSL', 'CUSR0000SA0L2', 'CUSR0000SA0L5', 'PCEPI', 'DDURRG3M086SBEA', 'DNDGRG3M086SBEA', 'DSERRG3M086SBEA', 'CES0600000008', 'CES2000000008', 'CES3000000008', 'UMCSENTx', 'DTCOLNVHFNM', 'DTCTHFNM', 'INVEST', 'VIXCLSx', 'RPI_MOM', 'W875RX1_MOM', 'DPCERA3M086SBEA_MOM', 'CMRMTSPLx_MOM', 'RETAILx_MOM', 'INDPRO_MOM', 'IPFPNSS_MOM', 'IPFINAL_MOM', 'IPCONGD_MOM', 'IPDCONGD_MOM', 'IPNCONGD_MOM', 'IPBUSEQ_MOM', 'IPMAT_MOM', 'IPDMAT_MOM', 'IPNMAT_MOM', 'IPMANSICS_MOM', 'IPFUELS_MOM', 'CLF16OV_MOM', 'CE16OV_MOM', 'UEMPLT5_MOM', 'UEMP5TO14_MOM', 'UEMP15OV_MOM', 'UEMP15T26_MOM', 'UEMP27OV_MOM', 'CLAIMSx_MOM', 'PAYEMS_MOM', 'USGOOD_MOM', 'CES1021000001_MOM', 'USCONS_MOM', 'MANEMP_MOM', 'DMANEMP_MOM', 'NDMANEMP_MOM', 'SRVPRD_MOM', 'USTPU_MOM', 'USWTRADE_MOM', 'USTRADE_MOM', 'USFIRE_MOM', 'USGOVT_MOM', 'ACOGNO_MOM', 'AMDMNOx_MOM', 'ANDENOx_MOM', 'AMDMUOx_MOM', 'BUSINVx_MOM', 'M2REAL_MOM', 'S&P 500_MOM', 'S&P PE ratio_MOM', 'TWEXAFEGSMTHx_MOM', 'EXSZUSx_MOM', 'EXJPUSx_MOM', 'EXUSUKx_MOM', 'EXCAUSx_MOM', 'M1SL_MOM', 'M2SL_MOM', 'BOGMBASE_MOM', 'TOTRESNS_MOM', 'BUSLOANS_MOM', 'REALLN_MOM', 'NONREVSL_MOM', 'WPSFD49207_
#   8.91616097e-01  1.17262575e+00  1.07847646e+00  1.07928653e+00
#   8.68363343e-01  1.05531586e+00  1.54864462e+00  1.68592497e+00
#   1.68433347e+00  2.05079891e+00  2.51039335e+00  2.81036168e+00
#   2.44119624e+00  2.17622347e+00  1.85634317e+00  1.64056581e+00
#   1.72510735e+00  1.92812156e+00  2.18056523e+00  2.02075775e+00
#   2.17249386e+00  2.12993072e+00  2.15131887e+00  2.26346893e+00
#   2.33094976e+00  2.47099630e+00  2.78192161e+00  2.80755069e+00
#   2.85412479e+00  2.64292386e+00  2.33205511e+00  2.49203247e+00
#   2.14732858e+00  2.00238090e+00  1.48758936e+00  1.51886154e+00
#   1.88318635e+00  2.00058347e+00  1.79591056e+00  1.67119489e+00
#   1.82633134e+00  1.73764121e+00  1.68449770e+00  1.73397370e+00
#   2.09229039e+00  2.31952747e+00  2.59976798e+00  2.34131668e+00
#   1.49403996e+00  3.13047294e-01  7.16656283e-01  9.96864763e-01
#   1.28106985e+00  1.39102289e+00  1.23038634e+00  1.17574521e+00
#   1.32041913e+00  1.35531998e+00  1.66750241e+00  2.62364575e+00
#   4.13737345e+00  4.92646656e+00  5.31741894e+00  5.26916765e+00
#   5.18132317e+00  5.36352343e+00  6.22659122e+00  6.86555952e+00
#   7.15945735e+00  7.57808246e+00  7.94922090e+00  8.54078015e+00
#   8.23516174e+00  8.53005171e+00  8.99929814e+00  8.44777821e+00
#   8.21625506e+00  8.20575158e+00  7.75726147e+00  7.13138037e+00
#   6.41083168e+00  6.34029631e+00  5.95764871e+00  4.93134864e+00
#   4.94694749e+00  4.12531454e+00  3.05925333e+00  3.28032820e+00
#   3.71863587e+00  3.69508233e+00  3.24653751e+00  3.13985564e+00
#   3.32220021e+00  3.10794259e+00  3.16642121e+00  3.46900144e+00
#   3.35404711e+00  3.23886640e+00  2.97008540e+00  2.93846331e+00
#   2.61091403e+00  2.43254146e+00  2.57140350e+00  2.71416840e+00]

# %%
selected_features = []
selected_coefficients = []

for feature, coef in zip(feature_names, lasso_cv.coef_):
    if abs(coef) > 0:
        selected_features.append(feature)
        selected_coefficients.append(coef)

# %%
sorted_idx = np.argsort(np.abs(selected_coefficients))[::-1]
sorted_features = [selected_features[i] for i in sorted_idx]
sorted_coefficients = [selected_coefficients[i] for i in sorted_idx]

# Print results
print(f"LASSO selected {len(sorted_features)} out of {len(feature_names)} features")
print(f"Optimal alpha: {lasso_cv.alpha_:.6f}")
# Out:
# LASSO selected 101 out of 293 features
# Optimal alpha: 0.002057

# %%
results = pl.DataFrame({
    'Feature': sorted_features[:20],
    'Coefficient': sorted_coefficients[:20]
})
print("\nTop 20 features by importance:")
print(results)
# Out:
# Top 20 features by importance:
# shape: (20, 2)
# ┌────────────────────────┬─────────────┐
# │ Feature                ┆ Coefficient │
# │ ---                    ┆ ---         │
# │ str                    ┆ f64         │
# ╞════════════════════════╪═════════════╡
# │ CUSR0000SA0L5_YOY_lag1 ┆ 0.640118    │
# │ ACOGNO_YOY_lag1        ┆ 0.326003    │
# │ TOTRESNS_YOY_lag1      ┆ -0.22804    │
# │ CUSR0000SAD_YOY_lag1   ┆ 0.22555     │
# │ AMDMUOx_YOY_lag1       ┆ 0.180176    │
# │ …                      ┆ …           │
# │ UEMP27OV_YOY_lag1      ┆ -0.102297   │
# │ WPSID61_YOY_lag1       ┆ -0.101362   │
# │ USTRADE_lag1           ┆ -0.099909   │
# │ CES3000000008_YOY_lag1 ┆ 0.08363     │
# │ RPI_YOY_lag1           ┆ 0.076648    │
# └────────────────────────┴─────────────┘

# %%
plt.figure(figsize=(10, 6))
alphas = lasso_cv.alphas_
mse = lasso_cv.mse_path_.mean(axis=1)
print(mse)
plt.semilogx(alphas, mse)
plt.axvline(lasso_cv.alpha_, color='k', linestyle='--')
plt.xlabel('Alpha')
plt.ylabel('Mean Squared Error')
plt.title('Cross-Validation Error vs. Alpha')
plt.tight_layout()
plt.show()
# Out:
# [  3.19281743   3.19281743   3.19281743   3.19281743   3.19281743
#    3.19281743   3.19281743   3.19281743   3.19281743   3.19281743
#    3.19281743   3.19281743   3.19281743   3.19281743   3.19281743
#    3.19281743   3.19281743   3.19281743   3.19281743   3.19281743
#    3.19281743   3.19281743   3.19281743   3.19281743   3.19281743
#    3.19281743   3.12151741   2.82110091   2.36967494   1.97416394
#    1.68230401   1.42892645   1.22383147   1.07103849   0.97351342
#    0.90418838   0.81572934   0.74155979   0.68983121   0.65298441
#    0.62620706   0.61670088   0.60325225   0.58252424   0.56814648
#    0.59021538   0.61591998   0.63216074   0.63463396   0.61037264
#    0.58363729   0.56247226   0.54830074   0.55701212   0.5637043
#    0.57449328   0.55892455   0.53643395   0.53579052   0.56915175
#    0.63610484   0.72166958   0.86859211   1.06465408   1.28165078
#    1.46039523   1.72612584   1.92247917   1.88018946   1.79157588
#    1.82592368   2.00477059   2.3348291    2.76500842   3.91908256
#    5.7396784    7.80052078   9.96625786  11.93500169  13.14882838
#   14.46308712  15.35827493  15.79367927  15.96231375  16.33100408
#   16.93667518  17.4554738   17.54319649  16.706709    16.63781325
#   18.21358737  21.68723757  27.34470184  35.47080724  45.57978368
#   57.01412925  69.6034899   82.75991181  95.39383989 108.03869913]

# %%
original_feature_names = [feature.replace('_lag1', '') for feature in sorted_features]

selected_data = df.select([
    'sasdate', 
    'CPIAUCSL_YOY',  
    *original_feature_names  
])

output_path = '../data/selected_features_inflation.csv'
selected_data.write_csv(output_path)

print(f"Saved {len(original_feature_names)} selected features and target variable to {output_path}")
print(f"Selected features: {original_feature_names[:10]}..." if len(original_feature_names) > 10 else original_feature_names)

feature_importance = pl.DataFrame({
    'Feature': sorted_features,
    'Coefficient': sorted_coefficients,
    'AbsCoefficient': [abs(c) for c in sorted_coefficients]
}).sort('AbsCoefficient', descending=True)

feature_importance.write_csv('../data/feature_importance_lasso.csv')
print(f"Saved feature importance information to ../data/feature_importance_lasso.csv")
# Out:
# Saved 101 selected features and target variable to ../data/selected_features_inflation.csv
# Selected features: ['CUSR0000SA0L5_YOY', 'ACOGNO_YOY', 'TOTRESNS_YOY', 'CUSR0000SAD_YOY', 'AMDMUOx_YOY', 'S&P PE ratio_MOM', 'HWIURATIO', 'OILPRICEx_YOY', 'USCONS_YOY', 'CPIMEDSL_YOY']...
# Saved feature importance information to ../data/feature_importance_lasso.csv
